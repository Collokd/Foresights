# %% [markdown]
# <a href="https://colab.research.google.com/github/Collokd/Foresights/blob/master/Week_5_Copy_of_Moringa_Data_Science_Prep_W5_Prep_Project_2020_04_Foresighters_Python_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prep Project: Week 5

# %% [markdown]
# **Research Question**
#
#
#
# **Possible Questions for Consideration**
#
#
#
# **Datasets Provided**

# %% [markdown]
# # Importing The Libraries

# %%
# Import the pandas library and the numpy library
#
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the Dataset

# %%
# Loading the data from the csv file into a dataframe to be used
#
child_labour = pd.read_csv("Kenya Child Labour Baseline Survey.csv", encoding='ISO-8859–1')
child_labour
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,5,9,10,11,12,13,17,19,20,26,28,29,31,57,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,82,83,84,87,88,89,90,91,92,93,95,106,107,108,109,110,111,112,115,116,117,118,119,121,122,125,126,143,144,170,175,207,208,209,210,211,212,213,214,215,216,217,222,224,225,226,227,228,232,233,234,235,236,237,238,239,240,241,242,245,246,248,249,250,251,252,253,255,256,258,259,260,261,262,263,264,265,266,267,268,269,270,272,273,274,279,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,304,305,306,307,308,309,310,311,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,334,335,336,337,338,339,340,341,344,345,346,347,348,349,350,351,353,354,355,356,357,358,359,360,361,365,366,374,378,379,383,384,385,386,387,388,389,390,391,392,394,395,396,399,400,401,407,408,409,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,43
# ...

# %% [markdown]
# # Previewing the Dataset

# %%
# Previewing the first 10 rows
#
child_labour.head(10)
# Out:
#   sno          ID DISTRICT  ... Unnamed: 685 Unnamed: 686 Unnamed: 687
# 0   2  3.0601E+11   kilifi  ...          NaN          NaN          NaN
# 1   3  3.0601E+11   kilifi  ...          NaN          NaN          NaN
# 2   4  3.0601E+11   kilifi  ...          NaN          NaN          NaN
# 3   5  3.0601E+11   kilifi  ...          NaN          NaN          NaN
# 4   6  3.0601E+11   kilifi  ...          NaN          NaN          NaN
# 5   7  3.0601E+11   kilifi  ...          NaN          NaN          NaN
# 6   8  3.0601E+11   kilifi  ...          NaN          NaN          NaN
# 7   9  3.0601E+11   kilifi  ...          NaN          NaN          NaN
# 8  11  3.0601E+11   kilifi  ...          NaN          NaN          NaN
# 9  13  3.0601E+11   kilifi  ...          NaN          NaN          NaN
#
# [10 rows x 688 columns]

# %% [markdown]
# # Accessing Information About the Dataset

# %%
# Checking the datatypes of the columns in the dataset
#
print(child_labour.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15762 entries, 0 to 15761
# Columns: 688 entries, sno to Unnamed: 687
# dtypes: float64(150), object(538)
# memory usage: 82.7+ MB
# None

# %%
child_labour.describe()
# Out:
#               A21  Unnamed: 393  ...  Unnamed: 683  Unnamed: 684
# count  318.000000           1.0  ...        1.0000           0.0
# mean    11.962264           0.0  ...       50.9585           NaN
# std      6.226419           NaN  ...           NaN           NaN
# min      0.000000           0.0  ...       50.9585           NaN
# 25%      7.250000           0.0  ...       50.9585           NaN
# 50%     14.000000           0.0  ...       50.9585           NaN
# 75%     16.000000           0.0  ...       50.9585           NaN
# max     29.000000           0.0  ...       50.9585           NaN
#
# [8 rows x 150 columns]

# %% [markdown]
# # Data Cleaning

# %%
# Irrelevant Data Observation: Dropping unneeded columns
#
child_labour.drop(["sno", "ID", "SUBLOC", "TYPE12", "hhsize", "CHILD_5_17", "A1", "A3", "HID", "fhead","A4", "A7", "A9", "A10", "A11", "A15", "A13", "A14", "A16", "A17", "A18A", "A18B", "A23", "A24", "A25A", "A26", "A27", "A28", "A29", "A30", "A31", "A32", "A33", "A34", "A35", "A37A", "A37B","A38"], axis = 1, inplace = True)
child_labour
# Out:
#       DISTRICT DIVISION LOCATION  ... Unnamed: 685 Unnamed: 686 Unnamed: 687
# 0       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 1       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 2       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 3       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 4       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# ...        ...      ...      ...  ...          ...          ...          ...
# 15757    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15758    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15759    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15760    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15761    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
#
# [15762 rows x 650 columns]

# %%
# Irrelevant Data Observation: Dropping unneeded columns
#
child_labour.drop(["A40A", "A40B", "A41", "A42", "A43", "A45A", "A45B", "A45C", "A45D", "A45E", "A45F", "A45G","A45H", "A45I", "A45J", "A45K", "A45L", "A45M", "A46A", "A46B","A46C", "A46D", "A46E", "A46F", "A46G", "A46H", "A47B", "A48", "A49", "A50", "A53", "A54", "A55", "A56", "A57", "A58", "A59", "A60", "A61", "A62", "A63", "A64", "A65", "A66", "A671"], axis = 1, inplace = True)
child_labour
# Out:
#       DISTRICT DIVISION LOCATION  ... Unnamed: 685 Unnamed: 686 Unnamed: 687
# 0       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 1       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 2       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 3       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 4       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# ...        ...      ...      ...  ...          ...          ...          ...
# 15757    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15758    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15759    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15760    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15761    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
#
# [15762 rows x 605 columns]

# %%
# Irrelevant Data Observation: Dropping unneeded rows
#
rows_needed = child_labour[child_labour["STATUS"] == "Completed"]
rows_needed
# Out:
#       DISTRICT DIVISION LOCATION  ... Unnamed: 685 Unnamed: 686 Unnamed: 687
# 0       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 1       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 2       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 3       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 4       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# ...        ...      ...      ...  ...          ...          ...          ...
# 15757    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15758    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15759    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15760    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15761    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
#
# [15385 rows x 605 columns]

# %%
# Dropping any duplicate columns from the dataset
#
df_consistent = rows_needed.drop_duplicates()
df_consistent
# Out:
#       DISTRICT DIVISION LOCATION  ... Unnamed: 685 Unnamed: 686 Unnamed: 687
# 0       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 1       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 2       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 3       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 4       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# ...        ...      ...      ...  ...          ...          ...          ...
# 15757    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15758    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15759    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15760    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15761    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
#
# [15317 rows x 605 columns]

# %%
# Fixing the messy columns in the dataset
#
df_consistent.columns = df_consistent.columns.str.lower().str.replace(' ','_')
df_consistent
# Out:
#       district division location  ... unnamed:_685 unnamed:_686 unnamed:_687
# 0       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 1       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 2       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 3       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# 4       kilifi   BAHARI     TEZO  ...          NaN          NaN          NaN
# ...        ...      ...      ...  ...          ...          ...          ...
# 15757    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15758    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15759    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15760    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
# 15761    busia   BUTULA   BUMALA  ...          NaN          NaN          NaN
#
# [15317 rows x 605 columns]

# %%
# Fixing the messy columns in the dataset
#
df_consistent.columns = ["ditrict", "division", "location", "type", "response_status", "sex", "age", "ever_attended_school", "highest_grade_attended", "reason_for_never_attending_school", "reason_for_dropping_out", "school_leaving_age", "attended_vocational_training", "main_activity", "average_monthly_income", "reason_for_main_activity", "age_at_first_job"]
df_consistent
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e650fef07a2e> in <module>()
# ----> 1 df_consistent.columns = ["ditrict", "division", "location", "type", "response_status", "sex", "age", "ever_attended_school", "highest_grade_attended", "reason_for_never_attending_school", "reason_for_dropping_out", "school_leaving_age", "attended_vocational_training", "main_activity", "average_monthly_income", "reason_for_main_activity", "age_at_first_job"]
#       2 df_consistent
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %%
rows_needed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15385 entries, 0 to 15761
# Columns: 605 entries, DISTRICT to Unnamed: 687
# dtypes: float64(150), object(455)
# memory usage: 71.1+ MB

# %%
# Checking and counting with any missing values in the dataset
#
print(df_consistent.isnull().any())

print(df_consistent.isnull().sum())

# %%
# Dealing with any missing values in the dataset
#
df_consistent.drop(["aged_5-17", "benefits_received_from_work", "reason_for_main_activity"], axis = 1, inplace = True)
df_consistent

# %% [markdown]
# # Exporting the Clean Dataset

# %% [markdown]
# # Data Analysis
